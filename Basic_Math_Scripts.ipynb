# %% [markdown]
# <a href="https://colab.research.google.com/github/trux66/Python/blob/main/Basic_Math_Scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lowest Common Denominator

# %% [markdown]
# This script first defines a function called lcm() that takes two numbers, x and y, as input.
#
# The function then finds the greater of the two numbers and stores it in the variable greater.
#
# The function then enters a while loop that continues until the lcm variable is assigned a value. Inside the loop, the function checks if greater is divisible by both x and y. If it is, then the lcm variable is assigned the value of greater and the loop is broken. Otherwise, the value of greater is incremented by 1.
#
# Finally, the script prompts the user to enter two numbers and then calls the lcm() function to find the least common multiple of the two numbers. The result is then printed to the console.
#
# *script generated by Google Bard

# %%
# find the lowest common denominator between two numbers

def lcm(x, y):
   greater = max(x, y)
   while(True):
       if((greater % x == 0) and (greater % y == 0)):
           lcm = greater
           break
       greater += 1
   return lcm

num1 = 7 # @param {type:"integer"}
num2 = 8 # @param {type:"integer"}

print("The LCM of", num1, "and", num2, "is", lcm(num1, num2))
# Out:
# The LCM of 7 and 8 is 56

# %% [markdown]
# # Power of Two

# %%
# determine the power of two for a given number
def power_of_two(n):
    """
    Determines the power of 2 value for a given number.

    Args:
        n (int): The number to evaluate.

    Returns:
        int: The power of 2 value for the given number.
    """
    power = 0
    while n > 0:
        if n % 2 == 0:
            n //= 2
            power += 1
        else:
            break

    return power

number = 256 # @param {type:"integer"}
power_of_two_value = power_of_two(number)

print(f"The power of 2 value for {number} is {power_of_two_value}")
# Out:
# The power of 2 value for 256 is 8
